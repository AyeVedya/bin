# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Personal/Studies/MSC Data Science Material/SEM2/ML/Practical/data_set/Fish.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
print("The different species are: ", list(dataset['Species'].unique()))
# Out:
# The different species are:  ['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt']

# %%
print("The data for the species Bream and Perch are: ")
dataframe=pd.DataFrame(dataset[dataset['Species'].isin(['Bream','Perch'])])
dataframe.index=range(len(dataframe))
dataframe
# Out:
# The data for the species Bream and Perch are:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0    Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1    Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2    Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3    Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4    Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..     ...     ...      ...      ...      ...      ...     ...
# 86   Perch  1100.0     39.0     42.0     44.6  12.8002  6.8684
# 87   Perch  1000.0     39.8     43.0     45.2  11.9328  7.2772
# 88   Perch  1100.0     40.1     43.0     45.5  12.5125  7.4165
# 89   Perch  1000.0     40.2     43.5     46.0  12.6040  8.1420
# 90   Perch  1000.0     41.1     44.0     46.6  12.4888  7.5958
#
# [91 rows x 7 columns]

# %%
dataframe
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0    Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1    Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2    Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3    Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4    Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..     ...     ...      ...      ...      ...      ...     ...
# 86   Perch  1100.0     39.0     42.0     44.6  12.8002  6.8684
# 87   Perch  1000.0     39.8     43.0     45.2  11.9328  7.2772
# 88   Perch  1100.0     40.1     43.0     45.5  12.5125  7.4165
# 89   Perch  1000.0     40.2     43.5     46.0  12.6040  8.1420
# 90   Perch  1000.0     41.1     44.0     46.6  12.4888  7.5958
#
# [91 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
scaler=StandardScaler()
dataframe.iloc[:,1:]=scaler.fit_transform(dataframe.iloc[:,1:])
xtrain,xtest,ytrain,ytest=train_test_split(dataframe.iloc[:,1:].values,dataframe['Species'].values, test_size=0.15)

# %%
ytest
# Out:
# array(['Perch', 'Bream', 'Perch', 'Perch', 'Bream', 'Perch', 'Perch',
#        'Bream', 'Perch', 'Perch', 'Bream', 'Perch', 'Bream', 'Bream'],
#       dtype=object)

# %%
xtrain
# Out:
# array([[-1.08637985, -1.15504774, -1.13614705, -1.17119417, -1.13963241,
#         -0.90212373],
#        [ 1.49019614,  1.42882797,  1.41730767,  1.5187712 ,  1.58779326,
#          0.91694411],
#        [ 0.08479106,  0.13689012,  0.10227849,  0.36432773,  0.81126219,
#         -0.03269948],
#        [-1.21130474, -1.31823989, -1.31488888, -1.36173339, -1.26648251,
#         -1.32657289],
#        [-0.69598955, -0.2846896 , -0.30627427, -0.45387007, -0.77608995,
#         -0.29731564],
#        [ 0.7874936 ,  0.58566853,  0.65127125,  0.89111261,  1.29895726,
#          0.70340721],
#        [ 0.6625687 ,  0.53127115,  0.52359852,  0.7005734 ,  1.21519825,
#          0.24389574],
#        [ 0.70941554,  0.59926788,  0.65127125,  0.84627986,  1.27163957,
#          0.3910094 ],
#        [ 0.3971033 ,  0.25928423,  0.26825305,  0.47640962,  1.08818813,
#          0.38495257],
#        [-1.10199546, -1.01905428, -1.00847432, -1.05911228, -1.04419194,
#         -1.07709881],
#        [ 0.08479106, -0.09429876, -0.02539425,  0.17378851,  0.80049513,
#          0.18204878],
#        [ 1.08419023,  1.30643386,  1.28963494,  1.07044364,  0.10452267,
#          1.09158269],
#        [-0.41490853,  0.27288358,  0.26825305,  0.48761781,  0.73955039,
#          0.04361657],
#         -0.93139841],
#        [ 0.08479106,  0.16408881,  0.14058031,  0.36432773,  0.84436346,
#         -0.13014714],
#        [ 0.77187799,  0.61286722,  0.65127125,  0.85748805,  1.29936874,
#          0.72817292],
#        [-0.69598955, -0.21669287, -0.2424379 , -0.39782913, -0.65319464,
#         -0.54093479],
#        [ 0.64695309,  0.58566853,  0.65127125,  0.85748805,  1.09518329,
#          0.75549595],
#        [-1.31592934, -1.69902157, -1.74897619, -1.76522819, -1.39111518,
#         -1.59926482],
#        [-0.53983342, -0.31188829, -0.33180881, -0.47628645, -0.53830031,
#          0.08702385],
#        [ 1.14665268,  0.68086395,  0.65127125,  0.48761781,  0.18530988,
#          1.87607673],
#        [ 0.25968591,  0.61286722,  0.58743489,  0.3979523 , -0.09630236,
#          0.92838478],
#        [ 1.1778839 ,  1.27923517,  1.28963494,  1.04802726,  0.28593957,
#          1.41219088],
#        [ 1.33404002,  1.29283451,  1.28963494,  1.07044364,  0.24053962,
#          1.49200643],
#        [-0.94583934, -0.81506409, -0.81696521, -0.89098945, -1.00647296,
#         -0.86342732],
#        [ 1.9586645 ,  1.56482143,  1.54498041,  1.30581561,  0.48518726,
#          1.25202138],
#        [-0.79592946, -0.33908699, -0.433947  , -0.55474378, -0.80233322,
#         -0.58144825],
#        [ 0.70941554,  0.95285087,  0.90661673,  0.72298978,  0.03594269,
#          0.84567541],
#        [ 1.50581175,  1.0208476 ,  1.09812583,  1.23856647,  1.69306353,
#          0.86411509],
#        [ 0.31902524,  0.5176718 ,  0.52359852,  0.73419797,  1.01743646,
#          0.37788627],
#        [ 0.70941554,  0.39527769,  0.39592578,  0.5996997 ,  0.95614882,
#          0.18669234],
#        [ 0.12851477,  0.40887704,  0.37039123,  0.11774757, -0.14808025,
#          0.67971828],
#        [-1.07076423, -1.01905428, -1.00847432, -1.05911228, -1.04419194,
#         -0.99802353],
#        [-1.37683023, -2.03900521, -2.06815803, -2.04543292, -1.63443694,
#         -2.02485805],
#        [-1.2331666 , -1.45423334, -1.42979435, -1.51864803, -1.25240075,
#         -1.26829273],
#        [ 1.6931991 ,  1.29283451,  1.28963494,  1.05923545,  0.38931245,
#          1.65177214],
#        [ 1.64635226,  1.6736162 ,  1.67265314,  1.37306474,  0.28689969,
#          1.52713604],
#        [-1.00830179, -0.88306082, -0.88080158, -0.94703039, -1.24798877,
#         -0.93005245],
#        [ 1.64635226,  1.85040769,  1.80032588,  1.52997939,  0.41400124,
#          1.74154781],
#        [ 0.42833452,  0.46327442,  0.45976215,  0.63332427,  1.13276512,
#          0.08466841],
#        [-1.22692035, -1.39983596, -1.39149253, -1.42898252, -1.15259403,
#         -1.31755495],
#        [-0.34307671, -0.16229549, -0.11476516,  0.06170662,  0.46913954,
#         -0.37181465],
#        [ 0.6625687 ,  0.88485414,  0.84278036,  0.67815702,  0.04645829,
#          1.24906027],
#        [-0.77406761, -0.74706736, -0.75312884, -0.8349485 , -0.77375823,
#         -0.86477328]])

# %%
xtest
# Out:
# array([[-1.0239174 , -0.74706736, -0.75312884, -0.8349485 , -0.98361296,
#         -0.79612921],
#        [ 1.39650247,  1.0208476 ,  1.09812583,  1.24977466,  1.68229647,
#          0.87373872],
#        [-1.16445791, -1.53582942, -1.51916526, -1.54106441, -1.24709723,
#         -1.13490788],
#        [-0.64914271, -0.2846896 , -0.30627427, -0.45387007, -0.82894226,
#         -0.45290887],
#        [-0.13382751, -0.1350968 , -0.11476516,  0.11774757,  0.40375997,
#          0.08480301],
#        [ 0.67818432,  0.96645021,  0.90661673,  0.71178159, -0.02424767,
#          0.91431948],
#        [-1.45834373, -2.71897251, -2.74482353, -2.70671607, -1.95813443,
#         -2.42272446],
#        [-0.07136506, -0.09429876, -0.02539425,  0.19620489,  0.66857012,
#         -0.05423488],
#        [ 1.9586645 ,  1.71441423,  1.67265314,  1.40668931,  0.41941906,
#          1.62088231],
#        [ 1.08419023,  1.23843713,  1.1619622 ,  0.93594537,  0.40085675,
#          1.57707124],
#        [ 0.75313925,  0.70806264,  0.77894399,  0.95836175,  1.33484745,
#          0.56766693],
#        [ 1.64635226,  1.72801358,  1.73648951,  1.46273026,  0.44033595,
#          2.10913008],
#        [ 1.41211808,  1.18403975,  1.22579857,  1.38427293,  1.8462712 ,
#          1.17213853],
#        [ 0.70941554,  0.39527769,  0.39592578,  0.62211608,  0.97388817,
#          0.12753731]])

# %%
ytrain
# Out:
# array(['Perch', 'Bream', 'Bream', 'Perch', 'Perch', 'Bream', 'Bream',
#        'Bream', 'Bream', 'Perch', 'Bream', 'Perch', 'Bream', 'Perch',
#        'Perch', 'Bream', 'Perch', 'Perch', 'Perch', 'Bream', 'Bream',
#        'Perch', 'Perch', 'Perch', 'Bream', 'Bream', 'Bream', 'Perch',
#        'Bream', 'Bream', 'Perch', 'Perch', 'Perch', 'Bream', 'Perch',
#        'Bream', 'Perch', 'Bream', 'Perch', 'Perch', 'Bream', 'Bream',
#        'Perch', 'Perch', 'Perch', 'Perch', 'Perch', 'Bream', 'Bream',
#        'Perch', 'Bream', 'Perch', 'Perch', 'Perch', 'Perch', 'Perch',
#        'Perch', 'Perch', 'Perch', 'Perch', 'Perch', 'Bream', 'Bream',
#        'Bream', 'Perch', 'Perch', 'Perch', 'Perch', 'Perch', 'Perch',
#        'Perch', 'Perch', 'Bream', 'Perch', 'Bream', 'Perch', 'Perch'],
#       dtype=object)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB_model=GaussianNB()
NB_model.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
print("Training R2 score: ",NB_model.score(xtrain,ytrain))
# Out:
# Training R2 score:  0.8311688311688312

# %%
ypred=NB_model.predict(xtest)
print("Predictions \n", ypred)
# Out:
# Predictions
#  ['Perch' 'Bream' 'Perch' 'Perch' 'Bream' 'Bream' 'Perch' 'Bream' 'Perch'
#  'Bream' 'Bream' 'Perch' 'Bream' 'Bream']

# %%
print("True Values \n", ytest)
# Out:
# True Values
#  ['Perch' 'Bream' 'Perch' 'Perch' 'Bream' 'Perch' 'Perch' 'Bream' 'Perch'
#  'Perch' 'Bream' 'Perch' 'Bream' 'Bream']

# %%
conf_mat=confusion_matrix(ytest, ypred)
print("Confusion Matrix \n", conf_mat)
print(classification_report(ytest,ypred))
print("Accuracy: ",(conf_mat[0][0]+conf_mat[1][1])/len(ytest))
# Out:
# Confusion Matrix
#  [[6 0]
#  [2 6]]
#               precision    recall  f1-score   support
#
#        Bream       0.75      1.00      0.86         6
#        Perch       1.00      0.75      0.86         8
#
#     accuracy                           0.86        14
#    macro avg       0.88      0.88      0.86        14
# weighted avg       0.89      0.86      0.86        14
#
# Accuracy:  0.8571428571428571

# %%
probs=NB_model.predict_proba(xtest)
probs=probs[:,1]
